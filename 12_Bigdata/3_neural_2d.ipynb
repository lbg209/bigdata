# %% [markdown]
# # Neural Network with 2D Data (2-dimensional)
# - Neural Network with 4 layers
# - 2D data f(x,y) -> R

# %% [markdown]
# ## 1.Import Required Libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch.autograd import Variable
#from visdom import Visdom
#viz = Visdom()

# %% [markdown]
# ## 2. Data Generation

# %%
num_data=1000
num_epoch=10000

x = init.uniform(torch.Tensor(num_data,1),-10,10)
y = init.uniform(torch.Tensor(num_data,1),-10,10)
z = x**2 + y**2

x_noise = x + init.normal(torch.FloatTensor(num_data,1),std=0.5)
y_noise = y + init.normal(torch.FloatTensor(num_data,1),std=0.5)
z_noise = x_noise**2 + y_noise**2

data_noise = torch.cat([x,y,z_noise],1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   if __name__ == '__main__':

# %%
# data visualization
'''
win_1=viz.scatter(
        X=data_noise,
        opts=dict(
            markersize=5,
            markercolor=np.ndarray(shape=[num_data,3],dtype=float,buffer=[51,153,255]*np.ones(shape=[num_data,3]))
            )
        )
'''

# %% [markdown]
# ## 3. Model & Optimizer

# %%
model = nn.Sequential(
            nn.Linear(2,20),
            nn.ReLU(),
            nn.Linear(20,10),
            nn.ReLU(),
            nn.Linear(10,5),
            nn.ReLU(),
            nn.Linear(5,5),
            nn.ReLU(),
            nn.Linear(5,1),
        )

loss_func = nn.L1Loss()
optimizer = optim.SGD(model.parameters(),lr=0.001)

# %% [markdown]
# ## 4. Train

# %%
input_data = torch.cat([x,y],1)
print(input_data)
print(input_data.size())
label = z_noise
loss_arr =[]

for i in range(num_epoch):
    optimizer.zero_grad()
    output = model(input_data)
    loss = loss_func(output,label)
    loss.backward()
    optimizer.step()
    
    loss_arr.append(loss.item())
    
    if i % 100 == 0 and i <1000:
        print(loss)
        data = torch.cat([input_data.cpu(),output.cpu().data],1)
      
#        win_2 =viz.scatter(
#                X=data,
#                opts=dict(
#                markersize=5,
#                markercolor=np.ndarray(shape=[num_data,3],dtype=float,buffer=128*np.ones(shape=[num_data,3]))
#            )
#    )
# Out:
# tensor([[-0.4775, -9.8042],
#         [-1.1825, -2.9409],
#         [-7.3808,  2.5466],
#         ...,
#         [-9.5117, -2.0003],
#         [-6.1871,  1.3888],
#         [ 4.6544, -7.8949]])
# torch.Size([1000, 2])
# tensor(5.8667, grad_fn=<L1LossBackward0>)
# tensor(5.8311, grad_fn=<L1LossBackward0>)
# tensor(6.0148, grad_fn=<L1LossBackward0>)
# tensor(5.7364, grad_fn=<L1LossBackward0>)
# tensor(5.8867, grad_fn=<L1LossBackward0>)
# tensor(5.7403, grad_fn=<L1LossBackward0>)
# tensor(6.0210, grad_fn=<L1LossBackward0>)
# tensor(5.8238, grad_fn=<L1LossBackward0>)
# tensor(5.8676, grad_fn=<L1LossBackward0>)
# tensor(5.7115, grad_fn=<L1LossBackward0>)

# %%
param_list = list(model.parameters())
print(param_list)
# Out:
# [Parameter containing:
# tensor([[-0.5311, -0.0723],
#         [-0.0066,  0.4739],
#         [-0.2977, -0.5986],
#         [-0.0738,  0.4109],
#         [-0.4271, -0.2820],
#         [-0.3134, -0.0115],
#         [ 0.6712, -0.3129],
#         [-0.6921, -0.1278],
#         [ 0.1818,  0.4482],
#         [-0.6347,  0.3345],
#         [-0.1327,  0.4770],
#         [ 0.2550,  0.2014],
#         [ 0.2971, -0.5434],
#         [-0.0618, -0.3469],
#         [-0.1885,  0.4517],
#         [ 0.0692, -0.2666],
#         [ 0.4484,  0.1728],
#         [ 0.6710,  0.1647],
#         [ 0.2344,  0.5705],
#         [ 0.0520,  0.4181]], requires_grad=True), Parameter containing:
# tensor([ 0.1145,  0.6106, -0.0240,  0.6741, -0.3534,  0.5426, -0.6989, -0.6088,
#         -0.0150, -0.7902, -0.8905,  0.6366,  0.2471, -1.5776, -0.8338, -1.1200,
#          0.2555, -0.9743, -1.2302,  0.6110], requires_grad=True), Parameter containing:
# tensor([[-0.0533,  0.0504, -0.1898,  0.1085, -0.1288,  0.0017,  0.0116,  0.0081,
#          -0.2200, -0.1353, -0.0920,  0.0703,  0.2018, -0.1384, -0.1782, -0.0875,
#          -0.1636, -0.1334,  0.1834, -0.0573],
#         [ 0.0725,  0.2701,  0.4761,  0.0776,  0.1964, -0.0279,  0.3072,  0.3424,
#           0.3803,  0.6155,  0.1059, -0.1040,  0.5522,  0.8967,  0.5254,  0.5002,
#           0.2856,  0.4746,  0.5109,  0.0912],
#         [-0.0588, -0.3223, -0.1140, -0.4901,  0.4259, -0.3387,  0.5042,  0.5038,
#           0.1463,  0.1175,  0.7861, -0.3319, -0.2629,  0.6124,  0.4661,  0.6233,
#          -0.1807,  0.4813,  0.7376, -0.2887],
#         [-0.1037,  0.2102,  0.0935,  0.1197, -0.1082,  0.2674, -0.0595, -0.2133,
#           0.1641,  0.0783, -0.0763,  0.1174, -0.1561,  0.0848, -0.1170, -0.0578,
#          -0.2546, -0.1144, -0.1921, -0.0961],
#         [-0.0742,  0.1549,  0.0723, -0.1347, -0.0457,  0.0810,  0.1051, -0.0742,
#           0.1768, -0.1397, -0.1936, -0.2377, -0.0239, -0.2267, -0.1651, -0.2122,
#           0.0278, -0.1907,  0.0599,  0.1815],
#         [ 0.1030, -0.1109,  0.1237, -0.2201,  0.2101,  0.0311,  0.3747, -0.1458,
#          -0.1920, -0.0439,  0.1107, -0.2307,  0.0156,  0.0830,  0.1176,  0.2918,
#           0.1162, -0.0778, -0.1881, -0.0590],
#         [ 0.2272, -0.0473, -0.2431,  0.1815, -0.0590,  0.1486, -0.1004, -0.0501,
#           0.1619, -0.1306, -0.0715,  0.1801, -0.1074,  0.1668, -0.2650, -0.0557,
#          -0.0658,  0.0956, -0.3110,  0.0541],
#         [-0.0923,  0.2692, -0.2003,  0.2188, -0.1081,  0.0252, -0.1769,  0.2138,
#          -0.1237, -0.0177,  0.0564,  0.2559,  0.1002,  0.0420, -0.1151, -0.1088,
#          -0.2064,  0.0904,  0.1031, -0.0460],
#         [-0.2925,  0.0743,  0.1405,  0.2135, -0.0040, -0.1057, -0.0287, -0.0073,
#           0.1299, -0.1745, -0.1992,  0.0058, -0.0782,  0.2925,  0.0649,  0.1960,
#          -0.2652, -0.2318, -0.2849,  0.2296],
#         [ 0.1032,  0.1193, -0.1326, -0.0568, -0.1583, -0.2279,  0.1854,  0.1263,
#           0.1641,  0.1394, -0.1694, -0.1617,  0.1897, -0.1073,  0.1182, -0.0989,
#          -0.0403,  0.0427, -0.0990, -0.2164]], requires_grad=True), Parameter containing:
# tensor([ 6.4239e-02, -9.2634e-01, -1.6511e+00, -1.4891e-01,  1.4312e-01,
#          1.9748e-01, -5.5143e-02,  2.7241e-01,  8.6169e-04, -1.6598e-01],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0277,  0.6978,  1.2606, -0.2651,  0.0448,  0.1055, -0.0367, -0.2964,
#          -0.5233,  0.2955],
#         [-0.1021,  1.2625,  1.3675, -0.2426,  0.2117,  0.3610,  0.3789,  0.0592,
#          -0.2158,  0.1082],
#         [ 0.3045, -0.1879,  0.1081,  0.0897,  0.0559,  0.2079,  0.0355,  0.2529,
#          -0.2204,  0.1338],
#         [-0.1854, -0.1236, -0.2850, -0.2745,  0.2614,  0.1726,  0.2184,  0.0833,
#          -0.2997,  0.1009],
#         [-0.2434,  0.2518, -0.3279,  0.2515,  0.2264, -0.0197, -0.0910,  0.0419,
#          -0.2129,  0.0287]], requires_grad=True), Parameter containing:
# tensor([-1.3419, -0.1054, -0.0195, -0.2021, -0.0094], requires_grad=True), Parameter containing:
# tensor([[-0.1656, -0.1259, -0.0281,  0.3923, -0.2162],
#         [-0.2780, -0.3224,  0.2759,  0.0144,  0.1035],
#         [ 0.2332, -0.1858, -0.4005,  0.3240, -0.4438],
#         [ 0.1025,  0.2101, -0.1033, -0.4195, -0.2333],
#         [ 2.0120,  1.8512, -0.0089, -0.2440, -0.0373]], requires_grad=True), Parameter containing:
# tensor([ 2.4088e-04, -2.0670e-01, -2.0778e-01, -6.7440e-01,  4.4787e-02],
#        requires_grad=True), Parameter containing:
# tensor([[-0.3839, -0.2919, -0.1586,  0.6840,  2.7098]], requires_grad=True), Parameter containing:
# tensor([1.4243], requires_grad=True)]

# %% [markdown]
# ## 5. Visualize Trained Output

# %%
data = torch.cat([input_data.cpu(),output.cpu().data],1)

win_2 =viz.scatter(
        X=data,
        opts=dict(
        markersize=5,
        markercolor=np.ndarray(shape=[num_data,3],dtype=float,buffer=128*np.ones(shape=[num_data,3]))
    )
)

# %% [markdown]
# ## 6. Visualize Loss Graph

# %%
x = np.reshape([i for i in range(num_epoch)],newshape=[num_epoch,1])
loss_data = np.reshape(loss_arr,newshape=[num_epoch,1])

win3=viz.line(
    X = x,
    Y = loss_data,
)
