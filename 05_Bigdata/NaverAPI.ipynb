# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

# %%
def clean_html(x):
  #https://predictor-ver1.tistory.com/4
  x = re.sub("\&\w*\;","",x)
  x = re.sub("<.*?>","",x)
  return x

# %%
client_id = "8y4FUmFdq2Ojofq_vHAA" #발급받은 ID 입력
client_secret = "dC9XGv5tQR" #발급받은 PW 입력
encText = urllib.parse.quote("해외여행") # 검색할 단어 입력
url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과
#url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    #print(result)
else:
    print("Error Code:" + rescode)

# %%
result_json = json.loads(result)

# %%
df_json = pd.DataFrame(result_json["items"])

# %%
df_json
# Out:
#                                       title  \
# 0                       모임·여행 등 '탈코로나' 시작되나
# 1          코로나로 줄어든 국제선 항공편, 연말까지 50% 회복 추진
# 2                  인천공항, 하루 여객 2만명… 회복 '시동'
# 3              인천공항 해외입국 격리 전면해제 첫주말 [포토뉴스]
# 4            2년 전 공항 시간당 편수 그대로…항공권 값만 ‘훨훨’
# 5  WHO 코로나19 혼합변이 XE, 전염력 더 높을수도…영·대만·태국 발견
# 6           영국·대만·태국 발견…혼합변이 XE, 전염력 더 높을수도
# 7                  늘어나는 캠핑객 … 병들어가는 자연발생유원지
# 8  WHO 혼합변이 XE, 전염력 더 높을수도…영·대만·태국 발견(종합2보)
# 9     하루 걸러 한집씩 개업 명동에 단체 관광객들 다시 발길 [현장르포]
#
#                                         originallink  \
# 0  http://www.kbmaeil.com/news/articleView.html?i...
# 1  http://www.mbn.co.kr/pages/news/newsView.php?n...
# 2  http://www.kyeongin.com/main/view.php?key=2022...
# 3    https://www.kyeonggi.com/article/20220403580133
# 4  http://www.ichannela.com/news/main/news_detail...
# 5  http://www.topstarnews.net/news/articleView.ht...
# 6  http://www.wowtv.co.kr/NewsCenter/News/Read?ar...
# 7  http://www.cctimes.kr/news/articleView.html?id...
# 8       http://yna.kr/AKR20220403051300009?did=1195m
# 9      http://www.fnnews.com/news/202204031844346051
#
#                                                 link  \
# 0  http://www.kbmaeil.com/news/articleView.html?i...
# 1  https://news.naver.com/main/read.naver?mode=LS...
# 2  http://www.kyeongin.com/main/view.php?key=2022...
# 3    https://www.kyeonggi.com/article/20220403580133
# 4  https://news.naver.com/main/read.naver?mode=LS...
# 5  http://www.topstarnews.net/news/articleView.ht...
# 6  https://news.naver.com/main/read.naver?mode=LS...
# 7  http://www.cctimes.kr/news/articleView.html?id...
# 8  https://news.naver.com/main/read.naver?mode=LS...
# 9  https://news.naver.com/main/read.naver?mode=LS...
#
#                                          description  \
# 0  격리면제 국가를 대상으로 한 해외여행 상품에 대한 문의와 판매가 급증하고 있으며 항...
# 1  해외 입국자 자가격리 조치가 면제되면서 해외여행 수요가 늘고 있지만, 여전히 방역 ...
# 2  지난달 정부가 해외입국자에 대한 의무 자가격리를 해제하면서 해외여행과 출장 등이 증...
# 3  인천국제공항공사는 정부의 방역지침 전환에 따라 지난 1일 입국장의 방역 안내소와 해...
# 4  자가격리가 사라지면서 꿈같던 해외여행, 떠나는 분들 많으시죠. 가고 싶은 사람은 많...
# 5  지난달 16일 이스라엘 보건부는 해외여행을 다녀온 2명이 유전자증폭(PCR) 검사를...
# 6  지난달 16일 이스라엘 보건부는 해외여행을 다녀온 2명이 유전자증폭(PCR) 검사를...
# 7  강순종 청주시 상당구 환경위생과 주무관 코로나19의 영향으로 해외여행이 어려워지고 ...
# 8  지난달 16일 이스라엘 보건부는 해외여행을 다녀온 2명이 유전자증폭(PCR) 검사를...
# 9  아직은 해외관광객 비중 상위권을 차지하던 동아시아 국가의 해외여행 자가격리가 여전해...
#
#                            pubDate
# 0  Sun, 03 Apr 2022 20:46:00 +0900
# 1  Sun, 03 Apr 2022 20:14:00 +0900
# 2  Sun, 03 Apr 2022 20:02:00 +0900
# 3  Sun, 03 Apr 2022 20:00:00 +0900
# 4  Sun, 03 Apr 2022 19:37:00 +0900
# 5  Sun, 03 Apr 2022 19:32:00 +0900
# 6  Sun, 03 Apr 2022 19:28:00 +0900
# 7  Sun, 03 Apr 2022 19:20:00 +0900
# 8  Sun, 03 Apr 2022 19:06:00 +0900
# 9  Sun, 03 Apr 2022 18:45:00 +0900

# %%
df_json['title'] = df_json['title'].apply(lambda x: clean_html(x))
df_json['description'] = df_json['description'].apply(lambda x: clean_html(x))

# %%
df_json
# Out:
#                                       title  \
# 0                       모임·여행 등 '탈코로나' 시작되나
# 1          코로나로 줄어든 국제선 항공편, 연말까지 50% 회복 추진
# 2                  인천공항, 하루 여객 2만명… 회복 '시동'
# 3              인천공항 해외입국 격리 전면해제 첫주말 [포토뉴스]
# 4            2년 전 공항 시간당 편수 그대로…항공권 값만 ‘훨훨’
# 5  WHO 코로나19 혼합변이 XE, 전염력 더 높을수도…영·대만·태국 발견
# 6           영국·대만·태국 발견…혼합변이 XE, 전염력 더 높을수도
# 7                  늘어나는 캠핑객 … 병들어가는 자연발생유원지
# 8  WHO 혼합변이 XE, 전염력 더 높을수도…영·대만·태국 발견(종합2보)
# 9     하루 걸러 한집씩 개업 명동에 단체 관광객들 다시 발길 [현장르포]
#
#                                         originallink  \
# 0  http://www.kbmaeil.com/news/articleView.html?i...
# 1  http://www.mbn.co.kr/pages/news/newsView.php?n...
